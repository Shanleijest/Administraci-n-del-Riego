# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
df = pd.read_csv('BA (1).csv')
df.head()
# Out:
#          Date   Adj Close  Rend Boeing
# 0  02/01/2018  282.886383     0.000000
# 1  03/01/2018  283.801239     0.003229
# 2  04/01/2018  282.724396    -0.003802
# 3  05/01/2018  294.322296     0.040203
# 4  08/01/2018  295.570740     0.004233

# %%
list_2=[]
for i in range(int(596/2)):
    list_2.append((i*2+1))
    df_2=[]
for i in list_2:
    df_2.append(np.mean(np.array([df['Rend Boeing'][i],df['Rend Boeing'][i+1]])))
Df_2=pd.DataFrame(df_2)
#Df_2.to_excel('ADMIN_2.xlsx')

# %%
list_3=[]
for i in range(int(594/3)):
    list_3.append((i*3+3))
df_3=[]
for i in list_3:
    df_3.append(np.mean(np.array([df['Rend Boeing'][i],df['Rend Boeing'][i+1],df['Rend Boeing'][i+2]])))
Df_3=pd.DataFrame(df_3)
#Df_3.to_excel('ADMIN_3.xlsx')

# %%
list_4=[]
for i in range(int(596/4)):
    list_4.append((i*4+1))
df_4=[]
for i in list_4:
    df_4.append(np.mean(np.array([df['Rend Boeing'][i],df['Rend Boeing'][i+1],df['Rend Boeing'][i+2],df['Rend Boeing'][i+3]])))
Df_4=pd.DataFrame(df_4)
#Df_4.to_excel('ADMIN_4.xlsx')

# %%
list_5=[]
for i in range(int(595/5)):
    list_5.append((i*5+2))
df_5=[]
for i in list_5:
    df_5.append(np.mean(np.array([df['Rend Boeing'][i],df['Rend Boeing'][i+1],df['Rend Boeing'][i+2],df['Rend Boeing'][i+3],df['Rend Boeing'][i+4]])))
Df_5=pd.DataFrame(df_5)
#Df_5.to_excel('ADMIN_5.xlsx')

# %%
list_6=[]
for i in range(int(594/6)):
    list_6.append((i*6+3))
df_6=[]
for i in list_6:
    df_6.append(np.mean(np.array([df['Rend Boeing'][i],df['Rend Boeing'][i+1],df['Rend Boeing'][i+2],df['Rend Boeing'][i+3],df['Rend Boeing'][i+4],df['Rend Boeing'][i+5]])))
Df_6=pd.DataFrame(df_6)
#Df_6.to_excel('ADMIN_6.xlsx')

# %%
list_7=[]
for i in range(int(595/7)):
    list_7.append((i*7+2))
df_7=[]
for i in list_7:
    df_7.append(np.mean(np.array([df['Rend Boeing'][i],df['Rend Boeing'][i+1],df['Rend Boeing'][i+2],df['Rend Boeing'][i+3],df['Rend Boeing'][i+4],df['Rend Boeing'][i+5],df['Rend Boeing'][i+6]])))
Df_7=pd.DataFrame(df_7)
#Df_7.to_excel('ADMIN_7.xlsx')

# %%
list_8=[]
for i in range(int(592/8)):
    list_8.append((i*8+5))
df_8=[]
for i in list_8:
    df_8.append(np.mean(np.array([df['Rend Boeing'][i],df['Rend Boeing'][i+1],df['Rend Boeing'][i+2],df['Rend Boeing'][i+3],df['Rend Boeing'][i+4],df['Rend Boeing'][i+5],df['Rend Boeing'][i+6],df['Rend Boeing'][i+7]])))
Df_8=pd.DataFrame(df_8)
#Df_8.to_excel('ADMIN_8.xlsx')

# %%
list_9=[]
for i in range(int(594/9)):
    list_9.append((i*9+3))
df_9=[]
for i in list_9:
    df_9.append(np.mean(np.array([df['Rend Boeing'][i],df['Rend Boeing'][i+1],df['Rend Boeing'][i+2],df['Rend Boeing'][i+3],df['Rend Boeing'][i+4],df['Rend Boeing'][i+5],df['Rend Boeing'][i+6],df['Rend Boeing'][i+7],df['Rend Boeing'][i+8]])))
Df_9=pd.DataFrame(df_9)
#Df_9.to_excel('ADMIN_9.xlsx')

# %%
list_10=[]
for i in range(int(590/10)):
    list_10.append((i*10+7))
df_10=[]
for i in list_10:
    df_10.append(np.mean(np.array([df['Rend Boeing'][i],df['Rend Boeing'][i+1],df['Rend Boeing'][i+2],df['Rend Boeing'][i+3],df['Rend Boeing'][i+4],df['Rend Boeing'][i+5],df['Rend Boeing'][i+6],df['Rend Boeing'][i+7],df['Rend Boeing'][i+8],df['Rend Boeing'][i+9]])))
Df_10=pd.DataFrame(df_10)
#Df_10.to_excel('ADMIN_10.xlsx')

# %%
list_11=[]
for i in range(int(594/11)):
    list_11.append((i*11+3))
df_11=[]
for i in list_11:
    df_11.append(np.mean(np.array([df['Rend Boeing'][i],df['Rend Boeing'][i+1],df['Rend Boeing'][i+2],df['Rend Boeing'][i+3],df['Rend Boeing'][i+4],df['Rend Boeing'][i+5],df['Rend Boeing'][i+6],df['Rend Boeing'][i+7],df['Rend Boeing'][i+8],df['Rend Boeing'][i+9],df['Rend Boeing'][i+10]])))
Df_11=pd.DataFrame(df_11)
#Df_11.to_excel('ADMIN_11.xlsx')

# %%
dfr = pd.read_excel('Rendimientos.xlsx')
dfr.columns
# Out:
# Index(['Date', 'S&P', 'Boenig', 'Rend S&P', 'Rend Boeing'], dtype='object')

# %%
fig, ax1 = plt.subplots(figsize=[12,5])
ax1.plot(dfr['S&P'], alpha=1, color='cyan')
ax1.set(ylabel='S&P 500',xlabel='Precio de cierre')
ax1.set_xticks(np.arange(0,630,20))

# %%
fig, ax1 = plt.subplots(figsize=[12,5])
ax1.plot(dfr['Boenig'], alpha=1, color='cyan')
ax1.set(ylabel='Boening',xlabel='Precio de cierre')
ax1.set_xticks(np.arange(0,630,20))

# %%
fig, ax1 = plt.subplots(figsize=[12,5])
ax1.plot(dfr['Rend S&P'], alpha=1, color='blue')
ax1.set(ylabel='Rendimientos',xlabel='Día')
ax1.set_xticks(np.arange(0,630,20))
ax1.plot(dfr['Rend Boeing'], alpha=1, color='cyan')
plt.legend(['S&P','Boeing'])
